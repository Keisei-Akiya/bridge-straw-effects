# %% [markdown]
# #  固定効果モデルでCATEを求める

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from patsy import dmatrix

# %%
filepath = '../../../../data/processed/df_filtered_5years_exclude_too_far_islands.xlsx'
df = pd.read_excel(filepath)
df = df[df['island_id'] != 191] # この島は変化率が無限大になるので除外
df.dropna(inplace=True)

# %%
df['population_change_rate'] = df.groupby('island_id')['population'].pct_change()
df['log_income'] = np.log(df['income'])
df['log_area'] = np.log(df['area_km2'])
df['log_distance'] = np.log(df['distance_m'])
df = df.dropna()

# %%
y = df['population_change_rate']
X = dmatrix('log_income + dummy_after_bridge_opened:log_income -1', data=df, return_type='dataframe')
islands = dmatrix('C(island_id) -1', data=df, return_type='dataframe')
years = dmatrix('C(year) -1', data=df, return_type='dataframe')

X = pd.concat([X, islands, years], axis=1)

model = sm.OLS(y, X)
result = model.fit()
print(result.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     population_change_rate   R-squared:                       0.266
# Model:                                OLS   Adj. R-squared:                  0.061
# Method:                     Least Squares   F-statistic:                     1.300
# Date:                    Tue, 29 Oct 2024   Prob (F-statistic):             0.0464
# Time:                            13:17:36   Log-Likelihood:                 272.25
# No. Observations:                     446   AIC:                            -348.5
# Df Residuals:                         348   BIC:                             53.32
# Df Model:                              97
# Covariance Type:                nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# log_income                              -0.0115      0.012     -0.934      0.351      -0.036       0.013
# dummy_after_bridge_opened:log_income     0.0061      0.007      0.843      0.400      -0.008       0.020
# C(island_id)[68]                        -0.0781      0.066     -1.178      0.240      -0.209       0.052
# C(island_id)[69]                         0.0239      0.072      0.334      0.738      -0.117       0.165
# C(island_id)[70]                         0.0184      0.069      0.265      0.791      -0.118       0.155
# C(island_id)[71]                         0.1756      0.072      2.452      0.015       0.035       0.316
# C(island_id)[72]                        -0.1371      0.091     -1.508      0.132      -0.316       0.042
# C(island_id)[73]                        -0.0220      0.072     -0.307      0.759      -0.163       0.119
# C(island_id)[76]                         0.0098      0.089      0.110      0.912      -0.166       0.186
# C(island_id)[77]                         0.0111      0.074      0.149      0.882      -0.135       0.157
# C(island_id)[78]                         0.0115      0.086      0.134      0.894      -0.158       0.181
# C(island_id)[79]                        -0.0043      0.086     -0.050      0.960      -0.173       0.165
# C(island_id)[80]                        -0.0152      0.073     -0.208      0.836      -0.160       0.129
# C(island_id)[88]                         0.0212      0.081      0.262      0.794      -0.138       0.180
# C(island_id)[90]                         0.0030      0.077      0.039      0.969      -0.149       0.155
# C(island_id)[91]                         0.0441      0.076      0.583      0.561      -0.105       0.193
# C(island_id)[93]                        -0.0452      0.075     -0.604      0.546      -0.192       0.102
# C(island_id)[94]                         0.0297      0.074      0.400      0.690      -0.117       0.176
# C(island_id)[95]                         0.0371      0.074      0.504      0.615      -0.108       0.182
# C(island_id)[99]                         0.1666      0.072      2.321      0.021       0.025       0.308
# C(island_id)[101]                       -0.0957      0.071     -1.349      0.178      -0.235       0.044
# C(island_id)[103]                        0.0746      0.074      1.005      0.316      -0.071       0.221
# C(island_id)[104]                       -0.0444      0.075     -0.593      0.554      -0.192       0.103
# C(island_id)[105]                       -0.0634      0.081     -0.779      0.437      -0.224       0.097
# C(island_id)[106]                       -0.0357      0.068     -0.524      0.600      -0.170       0.098
# C(island_id)[108]                       -0.0445      0.075     -0.592      0.554      -0.192       0.103
# C(island_id)[109]                       -0.0538      0.065     -0.827      0.409      -0.182       0.074
# C(island_id)[110]                       -0.0558      0.081     -0.685      0.494      -0.216       0.104
# C(island_id)[111]                        0.0074      0.076      0.098      0.922      -0.142       0.157
# C(island_id)[112]                       -0.0699      0.078     -0.894      0.372      -0.224       0.084
# C(island_id)[113]                        0.0321      0.076      0.424      0.672      -0.117       0.181
# C(island_id)[114]                        0.0501      0.094      0.532      0.595      -0.135       0.236
# C(island_id)[115]                        0.2198      0.094      2.332      0.020       0.034       0.405
# C(island_id)[117]                       -0.0040      0.070     -0.057      0.955      -0.142       0.134
# C(island_id)[118]                        0.2528      0.073      3.458      0.001       0.109       0.397
# C(island_id)[119]                        0.0024      0.069      0.035      0.972      -0.133       0.138
# C(island_id)[125]                       -0.0147      0.081     -0.182      0.856      -0.173       0.144
# C(island_id)[126]                        0.0441      0.071      0.625      0.532      -0.095       0.183
# C(island_id)[128]                        0.0656      0.071      0.929      0.353      -0.073       0.204
# C(island_id)[129]                       -0.0850      0.071     -1.205      0.229      -0.224       0.054
# C(island_id)[130]                       -0.0953      0.074     -1.295      0.196      -0.240       0.049
# C(island_id)[132]                       -0.0504      0.077     -0.659      0.510      -0.201       0.100
# C(island_id)[135]                       -0.0037      0.071     -0.053      0.958      -0.143       0.135
# C(island_id)[136]                        0.0650      0.089      0.727      0.468      -0.111       0.241
# C(island_id)[138]                        0.0189      0.074      0.255      0.799      -0.127       0.165
# C(island_id)[139]                       -0.0294      0.076     -0.384      0.701      -0.180       0.121
# C(island_id)[140]                       -0.0276      0.079     -0.351      0.726      -0.182       0.127
# C(island_id)[143]                       -0.0144      0.076     -0.190      0.850      -0.163       0.135
# C(island_id)[144]                        0.0196      0.078      0.250      0.803      -0.135       0.174
# C(island_id)[145]                        0.0249      0.078      0.318      0.751      -0.129       0.179
# C(island_id)[146]                        0.0108      0.085      0.128      0.898      -0.155       0.177
# C(island_id)[148]                        0.0032      0.078      0.041      0.968      -0.151       0.157
# C(island_id)[153]                       -0.0487      0.073     -0.665      0.506      -0.193       0.095
# C(island_id)[155]                        0.0572      0.074      0.771      0.441      -0.089       0.203
# C(island_id)[157]                       -0.0412      0.074     -0.555      0.579      -0.187       0.105
# C(island_id)[160]                        0.0488      0.075      0.650      0.516      -0.099       0.196
# C(island_id)[162]                        0.0350      0.071      0.495      0.621      -0.104       0.174
# C(island_id)[163]                        0.0848      0.071      1.200      0.231      -0.054       0.224
# C(island_id)[165]                        0.0592      0.071      0.831      0.407      -0.081       0.199
# C(island_id)[166]                       -0.0464      0.071     -0.650      0.516      -0.187       0.094
# C(island_id)[167]                       -0.0273      0.071     -0.382      0.702      -0.167       0.113
# C(island_id)[170]                       -0.1508      0.085     -1.767      0.078      -0.319       0.017
# C(island_id)[171]                        0.0173      0.074      0.234      0.815      -0.128       0.163
# C(island_id)[172]                        0.0486      0.074      0.656      0.512      -0.097       0.194
# C(island_id)[173]                        0.0145      0.074      0.195      0.845      -0.131       0.160
# C(island_id)[174]                        0.0141      0.074      0.190      0.849      -0.132       0.160
# C(island_id)[175]                       -0.0018      0.077     -0.024      0.981      -0.153       0.149
# C(island_id)[182]                       -0.0349      0.072     -0.481      0.630      -0.177       0.108
# C(island_id)[187]                        0.0129      0.076      0.170      0.865      -0.136       0.162
# C(island_id)[188]                       -0.0108      0.076     -0.142      0.887      -0.160       0.138
# C(island_id)[189]                        0.0149      0.069      0.216      0.829      -0.121       0.151
# C(island_id)[190]                        0.0784      0.071      1.103      0.271      -0.061       0.218
# C(island_id)[192]                       -0.0121      0.074     -0.163      0.870      -0.158       0.134
# C(island_id)[193]                        0.0213      0.075      0.285      0.776      -0.126       0.168
# C(island_id)[194]                       -0.0604      0.078     -0.774      0.440      -0.214       0.093
# C(island_id)[196]                       -0.1100      0.078     -1.408      0.160      -0.264       0.044
# C(island_id)[197]                       -0.1005      0.074     -1.362      0.174      -0.246       0.045
# C(island_id)[198]                       -0.0545      0.095     -0.574      0.567      -0.241       0.132
# C(island_id)[199]                       -0.0437      0.073     -0.594      0.553      -0.188       0.101
# C(island_id)[200]                       -0.0108      0.076     -0.143      0.886      -0.159       0.138
# C(island_id)[201]                       -0.1266      0.076     -1.675      0.095      -0.275       0.022
# C(island_id)[202]                       -0.0636      0.075     -0.850      0.396      -0.211       0.084
# C(island_id)[204]                       -0.0789      0.076     -1.041      0.299      -0.228       0.070
# C(island_id)[206]                        0.0508      0.086      0.590      0.555      -0.119       0.220
# C(island_id)[207]                        0.0780      0.086      0.906      0.365      -0.091       0.247
# C(island_id)[215]                       -0.0207      0.072     -0.289      0.772      -0.161       0.120
# C(island_id)[216]                       -0.0208      0.069     -0.299      0.765      -0.157       0.116
# C(island_id)[217]                       -0.0320      0.074     -0.432      0.666      -0.178       0.114
# C(island_id)[218]                        0.0276      0.074      0.373      0.709      -0.118       0.173
# C(island_id)[221]                       -0.0787      0.073     -1.076      0.283      -0.222       0.065
# C(island_id)[223]                       -0.0349      0.073     -0.477      0.634      -0.179       0.109
# C(island_id)[226]                       -0.0372      0.076     -0.492      0.623      -0.186       0.111
# C(year)[1990]                           -0.0030      0.132     -0.023      0.982      -0.262       0.256
# C(year)[1995]                           -0.0066      0.117     -0.056      0.955      -0.237       0.224
# C(year)[2000]                           -0.0518      0.084     -0.620      0.535      -0.216       0.112
# C(year)[2005]                            0.0120      0.094      0.127      0.899      -0.174       0.198
# C(year)[2010]                           -0.0396      0.095     -0.417      0.677      -0.227       0.147
# C(year)[2015]                           -0.0557      0.094     -0.594      0.553      -0.240       0.129
# C(year)[2020]                           -0.0851      0.094     -0.910      0.364      -0.269       0.099
# ==============================================================================
# Omnibus:                      184.202   Durbin-Watson:                   2.598
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3951.294
# Skew:                           1.237   Prob(JB):                         0.00
# Kurtosis:                      17.370   Cond. No.                     1.56e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.82e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
