# %% [markdown]
# # Bayse Model 負の二項分布

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymc as pm
import arviz as az
az.style.use('arviz-darkgrid')
from patsy import dmatrix

import sys
import os
sys.path.append(os.path.abspath('../../../../../data_cleaning'))

from log_standardize import log_standardize

# %%
filepath = "../../../../../../data/processed/df_filtered_5years.xlsx"
df = pd.read_excel(filepath)
df = df.dropna()

# %% [markdown]
# ## Difine variables

# %%
population = df['population']
bridge = df['dummy_after_bridge_opened']
pop_density = df['population'] / df['area_km2']

log_std_income = log_standardize(df['income'])
log_std_area = log_standardize(df['area_km2'])
log_std_dist = log_standardize(df['distance_m'])
log_std_density = log_standardize(pop_density)

X = dmatrix('log_std_income + log_std_area + log_std_dist + log_std_density', data=df, return_type='dataframe')
islands = dmatrix('C(island_id)', data=df, return_type='dataframe')
years = dmatrix('C(year)', data=df, return_type='dataframe')

n_x = X.shape[1]
n_islands = islands.shape[1]
n_years = years.shape[1]

# 過分散パラメータ
mean_population = np.mean(df['population'])
var_population = np.var(df['population'])

alpha = (var_population - mean_population) / mean_population**2
shape = 1 / alpha

# %% [markdown]
# ## Define the model

# %%
with pm.Model() as model:
    # Hyper-priors
    mu_islands = pm.Normal('mu_islands', mu=0, sigma=100)
    sigma_islands = pm.HalfStudentT('sigma_islands', nu=3, sigma=100)
    
    # prior
    intercept_islands = pm.Normal('intercept_islands', mu=mu_islands, sigma=sigma_islands, shape=n_islands, dims='island')
    beta_bridge = pm.Normal('beta_bridge', mu=0, sigma=100)
    gamma = pm.Normal('gamma', mu=0, sigma=100, shape=n_x, dims='X')
    delta = pm.Normal('delta', mu=0, sigma=100, shape=n_years, dims='years')

    # log link function
    lambda_ = pm.math.exp(beta_bridge * bridge + pm.math.dot(X, gamma) + pm.math.dot(islands, intercept_islands) + pm.math.dot(years, delta))

    # likelihood
    Y_obs = pm.NegativeBinomial('Y_obs', mu=lambda_, alpha=alpha, observed=population)


# view model
pm.model_to_graphviz(model)

# %%
with model:
    idata = pm.sample(
        draws=1000,
        tune=2000,
        nuts_sampler="numpyro",
        return_inferencedata=True,
        target_accept=.9,
        chains=2,
    )
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#   0%|          | 0/3000 [00:00<?, ?it/s]
#   0%|          | 0/3000 [00:00<?, ?it/s]

# %%
az.to_netcdf(idata, './bm_covariates.nc')
# Out:
# './bm_covariates.nc'

# %%
az.plot_trace(idata, figsize=(16, 12))  # サイズを調整
az.summary(idata)
# Out:
#                mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# beta_bridge  -0.009   0.027   -0.057    0.043      0.010    0.008       7.0
# gamma[0]     33.829  43.453  -39.734  119.254     23.855   18.623       3.0
# gamma[1]      0.026   0.011    0.010    0.048      0.002    0.002      25.0
# gamma[2]      1.535   0.014    1.506    1.555      0.003    0.002      19.0
# gamma[3]      0.024   0.012   -0.002    0.044      0.004    0.003      15.0
# gamma[4]      1.188   0.013    1.163    1.213      0.003    0.002      25.0
# delta[0]    -28.417  43.418 -113.808   45.105     23.828   18.601       3.0
# delta[1]      0.061   0.217   -0.285    0.398      0.128    0.102       3.0
# delta[2]      0.246   0.084    0.108    0.402      0.047    0.039       4.0
# delta[3]      0.236   0.084    0.110    0.415      0.047    0.039       4.0
# delta[4]      0.201   0.089    0.076    0.376      0.052    0.043       4.0
# delta[5]      0.189   0.090    0.046    0.356      0.051    0.043       4.0
# delta[6]      0.189   0.084    0.040    0.352      0.048    0.040       4.0
# delta[7]      0.180   0.087    0.047    0.360      0.046    0.040       4.0
#
#              ess_tail  r_hat
# beta_bridge      22.0   1.25
# gamma[0]         12.0   1.63
# gamma[1]         71.0   1.05
# gamma[2]         33.0   1.07
# gamma[3]         17.0   1.17
# gamma[4]         56.0   1.12
# delta[0]         12.0   1.63
# delta[1]         45.0   1.61
# delta[2]         14.0   1.61
# delta[3]         12.0   1.64
# delta[4]         12.0   1.79
# delta[5]         12.0   1.89
# delta[6]         11.0   1.70
# delta[7]         11.0   1.71

# %%
az.plot_posterior(idata, var_names=['beta_bridge', 'gamma', 'delta'], figsize=(12, 6));

# %% [markdown]
# # パラメータが0以上である確率

# %%
posterior_samples = idata.posterior

intercept_samples = posterior_samples['intercept']
beta_bridge_samples = posterior_samples['beta_bridge']
beta_income_samples = posterior_samples['gamma'][:, :, 0]
beta_area_samples = posterior_samples['gamma'][:, :, 1]
beta_distance_samples = posterior_samples['gamma'][:, :, 2]

# 0以上のサンプルの割合を計算
prob_beta_intercept_positive = np.mean(intercept_samples > 0)
prob_beta_bridge_positive = np.mean(beta_bridge_samples > 0)
prob_gamma_income_positive = np.mean(beta_income_samples > 0)
prob_gamma_area_positive = np.mean(beta_area_samples > 0)
prob_gamma_distance_positive = np.mean(beta_distance_samples > 0)

print(f"Pr(intercept > 0) = {prob_beta_intercept_positive:.4f}")
print(f"Pr(beta_bridge > 0) = {prob_beta_bridge_positive:.4f}")
print(f"Pr(gamma_income > 0) = {prob_gamma_income_positive:.4f}")
print(f"Pr(gamma_area > 0) = {prob_gamma_area_positive:.4f}")
print(f"Pr(gamma_distance > 0) = {prob_gamma_distance_positive:.4f}")
# Out:
# Pr(intercept > 0) = 1.0000
# Pr(beta_bridge > 0) = 1.0000
# Pr(gamma_income > 0) = 0.0070
# Pr(gamma_area > 0) = 1.0000
# Pr(gamma_distance > 0) = 0.0000

# %%
with pm.Model() as model:
    # 事前分布
    intercept = pm.Normal('intercept', mu=6.3, sigma=100)
    beta_bridge = pm.Normal('beta_bridge', mu=0.5, sigma=100)
    gamma = pm.Normal('gamma', mu=0, sigma=100, shape=3, dims='X')
    delta = pm.Normal('delta', mu=0, sigma=100, shape=3, dims='X')

    # 交差項の計算
    interaction = bridge * X

    # 対数リンク関数
    lambda_ = pm.math.exp(intercept + beta_bridge * bridge + pm.math.dot(X.T, gamma) + pm.math.dot(interaction.T, delta))

    # 尤度
    Y_obs = pm.NegativeBinomial('Y_obs', mu=lambda_, alpha=alpha, observed=population)


# モデルの視覚化
pm.model_to_graphviz(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 9
#       6 delta = pm.Normal('delta', mu=0, sigma=100, shape=3, dims='X')
#       8 # 交差項の計算
# ----> 9 interaction = bridge * X
#      11 # 対数リンク関数
#      12 lambda_ = pm.math.exp(intercept + beta_bridge * bridge + pm.math.dot(X.T, gamma) + pm.math.dot(interaction.T, delta))
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/series.py:6115, in Series._arith_method(self, other, op)
#    6113 def _arith_method(self, other, op):
#    6114     self, other = self._align_for_op(other)
# -> 6115     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/base.py:1384, in IndexOpsMixin._arith_method(self, other, op)
#    1381 with np.errstate(all="ignore"):
#    1382     result = ops.arithmetic_op(lvalues, rvalues, op)
# -> 1384 return self._construct_result(result, name=res_name)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/series.py:6211, in Series._construct_result(self, result, name)
#    6208 # TODO: result should always be ArrayLike, but this fails for some
#    6209 #  JSONArray tests
#    6210 dtype = getattr(result, "dtype", None)
# -> 6211 out = self._constructor(result, index=self.index, dtype=dtype, copy=False)
#    6212 out = out.__finalize__(self)
#    6214 # Set the result's name after __finalize__ is called because __finalize__
#    6215 #  would set it back to self.name
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/series.py:574, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     572     index = default_index(len(data))
#     573 elif is_list_like(data):
# --> 574     com.require_length_match(data, index)
#     576 # create/copy the manager
#     577 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (3) does not match length of index (830)

# %%
with model:
    pm.compute_log_likelihood(idata)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 2
#       1 with model:
# ----> 2     pm.compute_log_likelihood(idata)
#       4 az.to_netcdf(idata, './bm_covariates.nc')
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/stats/log_density.py:63, in compute_log_likelihood(idata, var_names, extend_inferencedata, model, sample_dims, progressbar, compile_kwargs)
#      31 def compute_log_likelihood(
#      32     idata: InferenceData,
#      33     *,
#    (...)
#      39     compile_kwargs: dict[str, Any] | None = None,
#      40 ):
#      41     """Compute elemwise log_likelihood of model given InferenceData with posterior group
#      42
#      43     Parameters
#    (...)
#      61         InferenceData with log_likelihood group
#      62     """
# ---> 63     return compute_log_density(
#      64         idata=idata,
#      65         var_names=var_names,
#      66         extend_inferencedata=extend_inferencedata,
#      67         model=model,
#      68         kind="likelihood",
#      69         sample_dims=sample_dims,
#      70         progressbar=progressbar,
#      71         compile_kwargs=compile_kwargs,
#      72     )
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/stats/log_density.py:205, in compute_log_density(idata, var_names, extend_inferencedata, model, kind, sample_dims, progressbar, compile_kwargs)
#     194 logdens_dataset = apply_function_over_dataset(
#     195     elemwise_logdens_fn,
#     196     posterior[[rv.name for rv in umodel.free_RVs]],
#    (...)
#     201     progressbar=progressbar,
#     202 )
#     204 if extend_inferencedata:
# --> 205     idata.add_groups({f"log_{kind}": logdens_dataset})
#     206     return idata
#     207 else:
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/data/inference_data.py:1543, in InferenceData.add_groups(self, group_dict, coords, dims, **kwargs)
#    1541 repeated_groups = [group for group in group_dict.keys() if group in self._groups]
#    1542 if repeated_groups:
# -> 1543     raise ValueError(f"{repeated_groups} group(s) already exists.")
#    1544 for group, dataset in group_dict.items():
#    1545     if group not in SUPPORTED_GROUPS_ALL:
#
# ValueError: ['log_likelihood'] group(s) already exists.

# %%
loo = az.loo(idata)
loo
# Out:
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/stats.py:795: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 12000 posterior samples and 830 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -7901.05   177.87
# p_loo       45.54        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.70]   (good)      828   99.8%
#    (0.70, 1]   (bad)         2    0.2%
#    (1, Inf)   (very bad)    0    0.0%
