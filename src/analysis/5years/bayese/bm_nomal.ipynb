# %% [markdown]
# # Bayse Model

# %%
import os
os.environ['PYTENSOR_FLAGS'] = 'blas_ldflags='

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, Predictive
import jax
jax.config.update("jax_platform_name", "cpu")
import jax.numpy as jnp
import pymc as pm
import arviz as az
from graphviz import Digraph
# Out:
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/configparser.py:320: UserWarning: PyTensor does not recognise this flag: blas_ldflags
#   warnings.warn(f"PyTensor does not recognise this flag: {key}")

# %%
filepath = "../../../data/processed/df_filtered_5years.xlsx"
df = pd.read_excel(filepath)
df['population_change_rate'] = df.groupby('island_id')['population'].pct_change()
df['log_income'] = np.log(df['income'])
df = df.dropna()
# Out:
# /tmp/ipykernel_3507/1695517033.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['population_change_rate'] = df.groupby('island_id')['population'].pct_change()

# %%
population = df['population_change_rate'].values
bridge = df['dummy_after_bridge_opened'].values
log_income = df['log_income'].values

with pm.Model() as model:
    # Priors
    alpha = pm.Normal('alpha', mu=0.0256, sigma=100)
    beta_bridge = pm.Normal('beta_bridge', mu=0.066, sigma=100)
    beta_income = pm.Normal('beta_income', mu=-0.0115, sigma=100)
    sigma = pm.HalfStudentT('sigma', nu=4, sigma=100)

    # linear model
    mu = alpha + beta_bridge * bridge + beta_income * log_income

    # Likelihood
    Y_obs = pm.Normal('Y_obs', mu=mu, sigma=sigma, observed=population)

# モデルの視覚化
graph = pm.model_to_graphviz(model)
graph.render(filename='../../visualization/graphviz/bayeisan_model_5years', format='png', cleanup=True)
graph

# %%
with model:
    idata = pm.sample(
        draws=10000,
        tune=1000,
        nuts_sampler="numpyro",
        return_inferencedata=True,
        chains=4,
        target_accept=.95,
    )
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#   0%|          | 0/11000 [00:00<?, ?it/s]
#   0%|          | 0/11000 [00:00<?, ?it/s]
#   0%|          | 0/11000 [00:00<?, ?it/s]
#   0%|          | 0/11000 [00:00<?, ?it/s]

# %%
az.to_netcdf(idata, '../mcmc_results/normal_5years.nc')
# Out:
# '../mcmc_results/normal_5years.nc'

# %%
az.plot_trace(idata, figsize=(18, 16))  # サイズを調整
az.summary(idata)
# Out:
#               mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha        0.093  0.071  -0.044    0.223      0.001      0.0   16693.0
# beta_bridge  0.066  0.015   0.038    0.095      0.000      0.0   24014.0
# beta_income -0.015  0.004  -0.022   -0.007      0.000      0.0   16755.0
# sigma        0.147  0.005   0.138    0.156      0.000      0.0   23556.0
#
#              ess_tail  r_hat
# alpha         19633.0    1.0
# beta_bridge   22373.0    1.0
# beta_income   19711.0    1.0
# sigma         21167.0    1.0

# %% [markdown]
# ## 予測

# %%
# 予測値のサンプリング (20秒弱掛かる)
posterior_predictive = pm.sample_posterior_predictive(idata, model=model)
# Out:
# Sampling: [Y_obs]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
Y_pred = posterior_predictive.posterior_predictive['Y_obs'].mean(axis=0)

# %% [markdown]
# ## 残差分析

# %%
# 残差の計算
residuals = population - Y_pred

# %% [markdown]
# ### 残差のプロット

# %%
plt.figure(figsize=(12, 6))
plt.scatter(Y_pred, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted Values")
plt.show()

# %% [markdown]
# ### 残差のヒストグラム

# %%
plt.figure(figsize=(12, 6))
plt.hist(residuals)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Histogram of Residuals")
plt.show()

# %%
# 残差のQQプロット
plt.figure(figsize=(12, 6))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("QQ Plot of Residuals")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 # 残差のQQプロット
#       2 plt.figure(figsize=(12, 6))
# ----> 3 stats.probplot(residuals, dist="norm", plot=plt)
#       4 plt.title("QQ Plot of Residuals")
#       5 plt.show()
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/scipy/stats/_morestats.py:635, in probplot(x, sparams, dist, fit, plot, rvalue)
#     632 osr = sort(x)
#     633 if fit:
#     634     # perform a linear least squares fit.
# --> 635     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     637 if plot is not None:
#     638     plot.plot(osm, osr, 'bo')
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/scipy/stats/_stats_py.py:10904, in linregress(x, y, alternative)
#   10899 ymean = np.mean(y, None)
#   10901 # Average sums of square differences from the mean
#   10902 #   ssxm = mean( (x-mean(x))^2 )
#   10903 #   ssxym = mean( (x-mean(x)) * (y-mean(y)) )
# > 10904 ssxm, ssxym, _, ssym = np.cov(x, y, bias=1).flat
#   10906 # R-value
#   10907 #   r = ssxym / sqrt( ssxm * ssym )
#   10908 if ssxm == 0.0 or ssym == 0.0:
#   10909     # If the denominator was going to be 0
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/numpy/lib/function_base.py:2683, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2681     if not rowvar and y.shape[0] != 1:
#    2682         y = y.T
# -> 2683     X = np.concatenate((X, y), axis=0)
#    2685 if ddof is None:
#    2686     if bias == 0:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 10000 and the array at index 1 has size 466

# %% [markdown]
# # 橋ダミーのパラメータが0以上である確率

# %%
posterior_samples = idata.posterior

beta_bridge_samples = posterior_samples['beta_bridge']

# 0以上のサンプルの割合を計算
prob_beta_bridge_positive = np.mean(beta_bridge_samples >= 0)

print(f"P(beta_1 >= 0) = {prob_beta_bridge_positive:.4f}")
# Out:
# P(beta_1 >= 0) = 1.0000
