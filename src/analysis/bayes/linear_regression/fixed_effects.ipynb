# %% [markdown]
# # ベイジアン 固定効果モデル

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
from patsy import dmatrix
import pymc as pm
import arviz as az
az.style.use('arviz-darkgrid')

# %%
filepath = '../../../../../data/processed/df_filtered.xlsx'
df = pd.read_excel(filepath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900 entries, 0 to 1899
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   island_names              1900 non-null   object
#  1   years                     1900 non-null   int64
#  2   island_ids                1900 non-null   int64
#  3   region_codes              1900 non-null   object
#  4   region_names              1900 non-null   object
#  5   prefecture_codes          1900 non-null   int64
#  6   populations               1697 non-null   float64
#  7   treatment_group           1900 non-null   int64
#  8   treatment_group_mainland  1900 non-null   int64
#  9   year_bridges_opened       1900 non-null   int64
#  10  after_treated             1900 non-null   int64
#  11  year_connect_mainland     1900 non-null   int64
#  12  after_treated_mainland    1900 non-null   int64
#  13  income                    1401 non-null   float64
#  14  prefecture_names          1900 non-null   object
#  15  area_km2                  1900 non-null   float64
#  16  distance_m                1900 non-null   float64
#  17  elementary_school         587 non-null    float64
#  18  junior_high_school        605 non-null    float64
#  19  high_school               646 non-null    float64
#  20  hospital                  207 non-null    float64
#  21  population_change_rate    1593 non-null   float64
#  22  control_group             1900 non-null   int64
#  23  time_since_intervention   1900 non-null   int64
# dtypes: float64(9), int64(11), object(4)
# memory usage: 356.4+ KB

# %%
# 標準化する列を選択
df['log_income'] = np.log(df['income'])
columns_to_scale = ['log_income', 'elementary_school', 'junior_high_school', 'high_school', 'hospital']

# 標準化
scaler = StandardScaler()
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])
# Out:
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# 0から始まるインデックスを振り直す
df['island_ids'], unique_island_ids = pd.factorize(df['island_ids'])
df['years'], unique_years = pd.factorize(df['years'])

COORDS = {
    'islands': df['island_ids'].unique(),
    'years': df['years'].unique(),
    'obs_id': df.index
}

y_values = df['populations'].values
log_income = df['log_income']
elementary_school = df['elementary_school']
junior_high_school = df['junior_high_school']
high_school = df['high_school']
hospital = df['hospital']

with pm.Model(coords=COORDS) as model:
    # Data
    islands = pm.Data('islands', df['island_ids'], dims='obs_id')
    years = pm.Data('years', df['years'], dims='obs_id')
    treatment = pm.Data('treatment', df['treatment_group'], dims='obs_id')
    bridge = pm.Data('bridge', df['after_treated'], dims='obs_id')

    # Priors
    beta_treatment = pm.Normal('beta_treatment', mu=0, sigma=100)
    beta_bridge = pm.Normal('beta_bridge', mu=0, sigma=100)
    gamma_income = pm.Normal('gamma_income', mu=0, sigma=100)
    gamma_elementary_school = pm.Normal('gamma_elementary_school', mu=0, sigma=100)
    gamma_junior_high_school = pm.Normal('gamma_junior_high_school', mu=0, sigma=100)
    gamma_high_school = pm.Normal('gamma_high_school', mu=0, sigma=100)
    gamma_hospital = pm.Normal('gamma_hospital', mu=0, sigma=100)

    mu_islands = pm.Normal('mu_islands', mu=0, sigma=100)
    sigma_islands = pm.HalfStudentT('sigma_islands', nu=3, sigma=100)
    z_islands = pm.Normal('z_islands', mu=0, sigma=1, dims='islands')
    delta_islands = pm.Deterministic('delta_islands', mu_islands + z_islands * sigma_islands)
    delta_years = pm.Normal('delta_year', mu=0, sigma=100, dims='years')
    sigma = pm.InverseGamma('sigma', alpha=0.001, beta=0.001)

    # linear model
    covariate = pm.Deterministic(
        'covariate',
        gamma_income * log_income + gamma_elementary_school * elementary_school + gamma_junior_high_school * junior_high_school + gamma_high_school * high_school + gamma_hospital * hospital
    )

    mu = pm.Deterministic(
        'mu',
        beta_treatment * treatment + beta_bridge * bridge + covariate + delta_islands[islands] + delta_years[years]
    )

    # Likelihood
    y_obs = pm.Gamma('y_obs', alpha=mu, beta=sigma, observed=y_values)
    # y_missing = pm.Data('y_missing', df['populations'].isnull(), dims='obs_id')

# モデルの視覚化
pm.model_to_graphviz(model)
# Out:
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/model/core.py:1359: ImputationWarning: Data in y_obs contains missing values and will be automatically imputed from the sampling distribution.
#   warnings.warn(impute_message, ImputationWarning)

# %%
with model:
    idata = pm.sample(
        draws=2000,
        tune=2000,
        nuts_sampler="numpyro",
        return_inferencedata=True,
        chains=2,
        cores=4,
        target_accept=.998,
    )
# Out:
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:763: RuntimeWarning: divide by zero encountered in power
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:763: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:763: RuntimeWarning: divide by zero encountered in power
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:763: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 with model:
# ----> 2     idata = pm.sample(
#       3         draws=2000,
#       4         tune=2000,
#       5         nuts_sampler="numpyro",
#       6         return_inferencedata=True,
#       7         chains=2,
#       8         cores=4,
#       9         target_accept=.998,
#      10     )
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/sampling/mcmc.py:727, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, **kwargs)
#     722         raise ValueError(
#     723             "Model can not be sampled with NUTS alone. Your model is probably not continuous."
#     724         )
#     726     with joined_blas_limiter():
# --> 727         return _sample_external_nuts(
#     728             sampler=nuts_sampler,
#     729             draws=draws,
#     730             tune=tune,
#     731             chains=chains,
#     732             target_accept=kwargs.pop("nuts", {}).get("target_accept", 0.8),
#     733             random_seed=random_seed,
#     734             initvals=initvals,
#     735             model=model,
#     736             var_names=var_names,
#     737             progressbar=progressbar,
#     738             idata_kwargs=idata_kwargs,
#     739             compute_convergence_checks=compute_convergence_checks,
#     740             nuts_sampler_kwargs=nuts_sampler_kwargs,
#     741             **kwargs,
#     742         )
#     744 if isinstance(step, list):
#     745     step = CompoundStep(step)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/sampling/mcmc.py:356, in _sample_external_nuts(sampler, draws, tune, chains, target_accept, random_seed, initvals, model, var_names, progressbar, idata_kwargs, compute_convergence_checks, nuts_sampler_kwargs, **kwargs)
#     353 elif sampler in ("numpyro", "blackjax"):
#     354     import pymc.sampling.jax as pymc_jax
# --> 356     idata = pymc_jax.sample_jax_nuts(
#     357         draws=draws,
#     358         tune=tune,
#     359         chains=chains,
#     360         target_accept=target_accept,
#     361         random_seed=random_seed,
#     362         initvals=initvals,
#     363         model=model,
#     364         var_names=var_names,
#     365         progressbar=progressbar,
#     366         nuts_sampler=sampler,
#     367         idata_kwargs=idata_kwargs,
#     368         compute_convergence_checks=compute_convergence_checks,
#     369         **nuts_sampler_kwargs,
#     370     )
#     371     return idata
#     373 else:
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/sampling/jax.py:599, in sample_jax_nuts(draws, tune, chains, target_accept, random_seed, initvals, jitter, model, var_names, nuts_kwargs, progressbar, keep_untransformed, chain_method, postprocessing_backend, postprocessing_vectorize, postprocessing_chunks, idata_kwargs, compute_convergence_checks, nuts_sampler)
#     593 vars_to_sample = list(
#     594     get_default_varnames(filtered_var_names, include_transformed=keep_untransformed)
#     595 )
#     597 (random_seed,) = _get_seeds_per_chain(random_seed, 1)
# --> 599 initial_points = _get_batched_jittered_initial_points(
#     600     model=model,
#     601     chains=chains,
#     602     initvals=initvals,
#     603     random_seed=random_seed,
#     604     jitter=jitter,
#     605 )
#     607 if nuts_sampler == "numpyro":
#     608     sampler_fn = _sample_numpyro_nuts
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/sampling/jax.py:228, in _get_batched_jittered_initial_points(model, chains, initvals, random_seed, jitter, jitter_max_retries)
#     211 def _get_batched_jittered_initial_points(
#     212     model: Model,
#     213     chains: int,
#    (...)
#     217     jitter_max_retries: int = 10,
#     218 ) -> np.ndarray | list[np.ndarray]:
#     219     """Get jittered initial point in format expected by NumPyro MCMC kernel
#     220
#     221     Returns
#    (...)
#     225         Each item has shape `(chains, *var.shape)`
#     226     """
# --> 228     initial_points = _init_jitter(
#     229         model,
#     230         initvals,
#     231         seeds=_get_seeds_per_chain(random_seed, chains),
#     232         jitter=jitter,
#     233         jitter_max_retries=jitter_max_retries,
#     234     )
#     235     initial_points_values = [list(initial_point.values()) for initial_point in initial_points]
#     236     if chains == 1:
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/sampling/mcmc.py:1327, in _init_jitter(model, initvals, seeds, jitter, jitter_max_retries)
#    1325 if i < jitter_max_retries:
#    1326     try:
# -> 1327         model.check_start_vals(point)
#    1328     except SamplingError:
#    1329         # Retry with a new seed
#    1330         seed = rng.randint(2**30, dtype=np.int64)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/model/core.py:1787, in Model.check_start_vals(self, start, **kwargs)
#    1781     valid_keys = ", ".join(value_names_set)
#    1782     raise KeyError(
#    1783         "Some start parameters do not appear in the model!\n"
#    1784         f"Valid keys are: {valid_keys}, but {extra_keys} was supplied"
#    1785     )
# -> 1787 initial_eval = self.point_logps(point=elem, **kwargs)
#    1789 if not all(np.isfinite(v) for v in initial_eval.values()):
#    1790     raise SamplingError(
#    1791         "Initial evaluation of model at starting point failed!\n"
#    1792         f"Starting values:\n{elem}\n\n"
#    1793         f"Logp initial evaluation results:\n{initial_eval}\n"
#    1794         "You can call `model.debug()` for more details."
#    1795     )
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/model/core.py:1819, in Model.point_logps(self, point, round_vals, **kwargs)
#    1816     point = self.initial_point()
#    1818 factors = self.basic_RVs + self.potentials
# -> 1819 factor_logps_fn = [pt.sum(factor) for factor in self.logp(factors, sum=False)]
#    1820 return {
#    1821     factor.name: np.round(np.asarray(factor_logp), round_vals)
#    1822     for factor, factor_logp in zip(
#    (...)
#    1825     )
#    1826 }
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/model/core.py:746, in Model.logp(self, vars, jacobian, sum)
#     744 rv_logps: list[TensorVariable] = []
#     745 if rvs:
# --> 746     rv_logps = transformed_conditional_logp(
#     747         rvs=rvs,
#     748         rvs_to_values=self.rvs_to_values,
#     749         rvs_to_transforms=self.rvs_to_transforms,
#     750         jacobian=jacobian,
#     751     )
#     752     assert isinstance(rv_logps, list)
#     754 # Replace random variables by their value variables in potential terms
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/logprob/basic.py:598, in transformed_conditional_logp(rvs, rvs_to_values, rvs_to_transforms, jacobian, **kwargs)
#     595     transform_rewrite = TransformValuesRewrite(values_to_transforms)  # type: ignore
#     597 kwargs.setdefault("warn_rvs", False)
# --> 598 temp_logp_terms = conditional_logp(
#     599     rvs_to_values,
#     600     extra_rewrites=transform_rewrite,
#     601     use_jacobian=jacobian,
#     602     **kwargs,
#     603 )
#     605 # The function returns the logp for every single value term we provided to it.
#     606 # This includes the extra values we plugged in above, so we filter those we
#     607 # actually wanted in the same order they were given in.
#     608 logp_terms = {}
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/logprob/basic.py:531, in conditional_logp(rv_values, warn_rvs, ir_rewriter, extra_rewrites, **kwargs)
#     528 node_values = remapped_vars[: len(node_values)]
#     529 node_inputs = remapped_vars[len(node_values) :]
# --> 531 node_logprobs = _logprob(
#     532     node.op,
#     533     node_values,
#     534     *node_inputs,
#     535     **kwargs,
#     536 )
#     538 if not isinstance(node_logprobs, list | tuple):
#     539     node_logprobs = [node_logprobs]
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/logprob/transform_value.py:84, in transformed_value_logprob(op, values, use_jacobian, *rv_outs, **kwargs)
#      82 rv_op = rv_outs[0].owner.op
#      83 rv_inputs = rv_outs[0].owner.inputs
# ---> 84 logprobs = _logprob(rv_op, values, *rv_inputs, **kwargs)
#      86 if not isinstance(logprobs, Sequence):
#      87     logprobs = [logprobs]
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/distributions/distribution.py:141, in DistributionMeta.__new__.<locals>.logp(op, values, *dist_params, **kwargs)
#     139     dist_params = [dist_params[i] for i in params_idxs]
#     140 [value] = values
# --> 141 return class_logp(value, *dist_params)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/distributions/continuous.py:2414, in Gamma.logp(value, alpha, scale)
#    2412 def logp(value, alpha, scale):
#    2413     beta = pt.reciprocal(scale)
# -> 2414     res = -pt.gammaln(alpha) + logpow(beta, alpha) - beta * value + logpow(value, alpha - 1)
#    2415     res = pt.switch(pt.ge(value, 0.0), res, -np.inf)
#    2416     return check_parameters(
#    2417         res,
#    2418         alpha > 0,
#    2419         beta > 0,
#    2420         msg="alpha > 0, beta > 0",
#    2421     )
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pymc/distributions/dist_math.py:97, in logpow(x, m)
#      93 """
#      94 Calculates log(x**m) since m*log(x) will fail when m, x = 0.
#      95 """
#      96 # return m * log(x)
# ---> 97 return pt.switch(pt.eq(x, 0), pt.switch(pt.eq(m, 0), 0.0, -np.inf), m * pt.log(x))
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/graph/op.py:293, in Op.__call__(self, name, return_list, *inputs, **kwargs)
#     249 def __call__(
#     250     self, *inputs: Any, name=None, return_list=False, **kwargs
#     251 ) -> Variable | list[Variable]:
#     252     r"""Construct an `Apply` node using :meth:`Op.make_node` and return its outputs.
#     253
#     254     This method is just a wrapper around :meth:`Op.make_node`.
#    (...)
#     291
#     292     """
# --> 293     node = self.make_node(*inputs, **kwargs)
#     294     if name is not None:
#     295         if len(node.outputs) == 1:
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:492, in Elemwise.make_node(self, *inputs)
#     486 """
#     487 If the inputs have different number of dimensions, their shape
#     488 is left-completed to the greatest number of dimensions with 1s
#     489 using DimShuffle.
#     490 """
#     491 inputs = [as_tensor_variable(i) for i in inputs]
# --> 492 out_dtypes, out_shapes, inputs = self.get_output_info(DimShuffle, *inputs)
#     493 outputs = [
#     494     TensorType(dtype=dtype, shape=shape)()
#     495     for dtype, shape in zip(out_dtypes, out_shapes)
#     496 ]
#     497 return Apply(self, inputs, outputs)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:431, in Elemwise.get_output_info(self, dim_shuffle, *inputs)
#     428         args.append(input)
#     429     else:
#     430         args.append(
# --> 431             dim_shuffle(
#     432                 input.type.broadcastable,
#     433                 ["x"] * difference + list(range(length)),
#     434             )(input)
#     435         )
#     436 inputs = args
#     438 # HERE: all the broadcast dims have the same length now
#     439
#     440 # cleverness: we iterate over the first, second, third broadcast flag
#    (...)
#     444 # it is multiplied by nout because Elemwise supports multiple outputs
#     445 # (nout of them)
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/tensor/elemwise.py:137, in DimShuffle.__init__(self, input_broadcastable, new_order)
#     136 def __init__(self, input_broadcastable, new_order):
# --> 137     super().__init__([self.c_func_file], self.c_func_name)
#     139     self.input_broadcastable = tuple(input_broadcastable)
#     140     if not all(isinstance(bs, bool | np.bool_) for bs in self.input_broadcastable):
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/link/c/op.py:315, in ExternalCOp.__init__(self, func_files, func_name)
#     312 self.func_name = func_name
#     313 self.code_sections: dict[str, str] = dict()
# --> 315 self.load_c_code(self.func_files)
#     317 if len(self.code_sections) == 0:
#     318     raise ValueError("No sections where defined in the C files")
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/link/c/op.py:335, in ExternalCOp.load_c_code(self, func_files)
#     333 """Loads the C code to perform the `Op`."""
#     334 for func_file in func_files:
# --> 335     func_file = self.get_path(func_file)
#     336     self.func_codes.append(func_file.read_text(encoding="utf-8"))
#     338 # If both the old section markers and the new section markers are
#     339 # present, raise an error because we don't know which ones to follow.
#
# File ~/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/pytensor/link/c/op.py:290, in ExternalCOp.get_path(cls, f)
#     288 if not f.is_absolute():
#     289     class_file = inspect.getfile(cls)
# --> 290     class_dir = Path(class_file).parent
#     291     f = (class_dir / f).resolve()
#     292 return f
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/pathlib.py:957, in Path.__new__(cls, *args, **kwargs)
#     954 _accessor = _normal_accessor
#     955 __slots__ = ()
# --> 957 def __new__(cls, *args, **kwargs):
#     958     if cls is Path:
#     959         cls = WindowsPath if os.name == 'nt' else PosixPath
#
# KeyboardInterrupt:

# %% [markdown]
# ## アウトプットの保存

# %%
az.to_netcdf(idata, 'fixed_effects.nc')
# Out:
# 'fixed_effects.nc'

# %% [markdown]
# ## アウトプットのエクスポート

# %%
idata = az.from_netcdf('fixed_effects.nc')

# %%
az.summary(idata)
# Out:
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# arviz - WARNING - Array contains NaN-value.
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/keisei/data-analysis/bridge-straw-effects/.venv/lib/python3.10/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                              mean     sd   hdi_3%  hdi_97%  mcse_mean  \
# beta_treatment             -0.905  0.014   -0.918   -0.891      0.010
# beta_bridge                -0.218  0.680   -0.898    0.462      0.480
# gamma_income               -0.649  0.350   -0.998   -0.299      0.247
# gamma_elementary_school    -0.137  0.094   -0.231   -0.044      0.066
# gamma_junior_high_school   -0.311  0.248   -0.559   -0.063      0.175
# ...                           ...    ...      ...      ...        ...
# y_obs[1895]               398.000  0.000  398.000  398.000      0.000
# y_obs[1896]               365.000  0.000  365.000  365.000      0.000
# y_obs[1897]               343.000  0.000  343.000  343.000      0.000
# y_obs[1898]               284.000  0.000  284.000  284.000      0.000
# y_obs[1899]               225.000  0.000  225.000  225.000      0.000
#
#                           mcse_sd  ess_bulk  ess_tail       r_hat
# beta_treatment              0.008       2.0       2.0  4876400.29
# beta_bridge                 0.407       2.0       2.0  4876400.29
# gamma_income                0.209       2.0       2.0  4876400.29
# gamma_elementary_school     0.056       2.0       2.0  4876400.29
# gamma_junior_high_school    0.148       2.0       2.0  4876400.29
# ...                           ...       ...       ...         ...
# y_obs[1895]                 0.000    4000.0    4000.0         NaN
# y_obs[1896]                 0.000    4000.0    4000.0         NaN
# y_obs[1897]                 0.000    4000.0    4000.0         NaN
# y_obs[1898]                 0.000    4000.0    4000.0         NaN
# y_obs[1899]                 0.000    4000.0    4000.0         NaN
#
# [6138 rows x 9 columns]

# %%
az.plot_trace(idata, figsize=(18, 15))  # サイズを調整

# %%
posterior_samples = idata.posterior

# 0以上のサンプルの割合を計算
prob_beta_bridge_positive = np.mean(posterior_samples['beta_bridge'] > 0)
print(f"Pr(beta_bridge > 0) = {prob_beta_bridge_positive:.4f}")
prob_beta_income_positive = np.mean(posterior_samples['gamma'] > 0)
print(f"Pr(gamma_income > 0) = {prob_beta_income_positive:.4f}")
prob_sigma_positive = np.mean(posterior_samples['sigma'] > 0)
print(f"Pr(sigma > 0) = {prob_sigma_positive:.4f}")
# Out:
# Pr(beta_bridge > 0) = 0.9205
# Pr(gamma_income > 0) = 0.1450
# Pr(sigma > 0) = 1.0000
