# %% [markdown]
# # 処置群

# %%
import pandas as pd

filepath = '../../data/processed/df_filtered_5years_exclude_too_far_islands_exclude_already_treatment.xlsx'
df = pd.read_excel(filepath)

# %%
df[df['treatment_group'] == 1][df['year'] == 2020][['island', 'island_id', 'prefecture_name', 'region_name', 'year_bridge']].sort_values('year_bridge')
# Out:
# /tmp/ipykernel_29225/917793127.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['treatment_group'] == 1][df['year'] == 2020][['island', 'island_id', 'prefecture_name', 'region_name', 'year_bridge']].sort_values('year_bridge')
#       island  island_id prefecture_name region_name  year_bridge
# 491      笠戸島        138             山口県         下松市         1970
# 557      島田島        157             徳島県         鳴門市         1971
# 381      沖野島        118             広島県        江田島市         1972
# 370  江田島・能美島        117             広島県        江田島市         1973
# 513       彦島        145             山口県         下関市         1975
# 326       鹿島        112             広島県          呉市         1975
# 458       長島        132             山口県         上関町         1976
# 403      屋代島        125             山口県       周防大島町         1976
# 755      伯方島        193             愛媛県         今治市         1979
# ...
