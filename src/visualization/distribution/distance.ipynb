# %% [markdown]
# # 距離の分布

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

filepath = '../../../data/processed/df_filtered_5years.xlsx'
df = pd.read_excel(filepath)
distance = df['distance_m']

# %%
plt.figure(figsize=(12, 6))
sns.histplot(distance, kde=True);

# %% [markdown]
# ## log scale

# %%
log_distance = np.log(distance)

plt.figure(figsize=(12, 6))
sns.histplot(log_distance, kde=True);

# %%
standardized_distance = (log_distance - log_distance.mean()) / log_distance.std()

plt.figure(figsize=(12, 6))
sns.histplot(standardized_distance, kde=True);
