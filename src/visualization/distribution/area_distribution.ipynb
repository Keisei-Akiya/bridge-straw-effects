# %% [markdown]
# # 面積の分布

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = '../../../data/processed/df_filtered_5years.xlsx'
df = pd.read_excel(filepath)
area_km2 = df['area_km2']
area = area_km2 * 1e6

# %%
plt.figure(figsize=(12, 6))
sns.histplot(area, kde=True);

# %% [markdown]
# ## 対数

# %%
log_area = np.log(area)
plt.figure(figsize=(12, 6))
sns.histplot(log_area, kde=True);

# %% [markdown]
# ## 標準化

# %%
standardized_area = (log_area - log_area.mean()) / log_area.std()
plt.figure(figsize=(12, 6))
sns.histplot(standardized_area, kde=True);
