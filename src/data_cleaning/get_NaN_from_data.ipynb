# %% [markdown]
# # 未入力を見つける

# %%
import pandas as pd

filepath = '../../data/raw/df.xlsx'
df = pd.read_excel(filepath)

# 人口が欠損している行を抽出
empty_population_rows = df[df['population'].isna()]
len(empty_population_rows)
# Out:
# 221

# %%
check_year = 1990
empty_population_rows[empty_population_rows['year'] == check_year]
# Out:
#         island  year  island_id region_code region_name  prefecture_code  \
# 123       瀬戸ヶ島  1990         67       32202         浜田市               32
# 242         長島  1990         72       33212        瀬戸内市               33
# 253   前島_黄島_黒島  1990         73       33361         牛窓町               33
# 657         向島  1990         91       34205         尾道市               34
# 668        岩子島  1990         92       34205         尾道市               34
# 716         因島  1990         94       34206      （旧）因島市               34
# 797       大久野島  1990         99       34203         竹原市               34
# 808         契島  1990        100       34427      （旧）大崎町               34
# 1052        鹿島  1990        112       34202          呉市               34
# 1063       大芝島  1990        113       34422     （旧）安芸津町               34
# 1074        似島  1990        114       34100         広島市               34
# 1085       金輪島  1990        115       34100         広島市               34
# ...
