# %% [markdown]
# # 全く同じ行を削除する

# %%
import pandas as pd

filepaths = '../../data/raw/df.xlsx'
df = pd.read_excel(filepaths)
df
# Out:
#      island  year  island_id  region_code region_name  prefecture_code  \
# 0        島後  1980          0        32528       隠岐の島町               32
# 1        島後  1985          0        32528       隠岐の島町               32
# 2        島後  1990          0        32528       隠岐の島町               32
# 3        島後  1995          0        32528       隠岐の島町               32
# 4        島後  2000          0        32528       隠岐の島町               32
# ...     ...   ...        ...          ...         ...              ...
# 5449    沖の島  2016        163        39208         宿毛市               39
# 5450    沖の島  2017        163        39208         宿毛市               39
# 5451    沖の島  2018        163        39208         宿毛市               39
# 5452    沖の島  2019        163        39208         宿毛市               39
# 5453    沖の島  2020        163        39208         宿毛市               39
#
#       population  dummy_island_has_bridge  dummy_island_is_connected_mainland  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      island  year  island_id  region_code region_name  prefecture_code  \
# 0        島後  1980          0        32528       隠岐の島町               32
# 1        島後  1985          0        32528       隠岐の島町               32
# 2        島後  1990          0        32528       隠岐の島町               32
# 3        島後  1995          0        32528       隠岐の島町               32
# 4        島後  2000          0        32528       隠岐の島町               32
# ...     ...   ...        ...          ...         ...              ...
# 5449    沖の島  2016        163        39208         宿毛市               39
# 5450    沖の島  2017        163        39208         宿毛市               39
# 5451    沖の島  2018        163        39208         宿毛市               39
# 5452    沖の島  2019        163        39208         宿毛市               39
# 5453    沖の島  2020        163        39208         宿毛市               39
#
#       population  dummy_island_has_bridge  dummy_island_is_connected_mainland  \
# ...

# %%
export_path = '../../data/raw/df.xlsx'
df.to_excel(export_path, index=False)
