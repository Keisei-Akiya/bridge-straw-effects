# %% [markdown]
# # 未入力を見つける

# %%
import pandas as pd

filepath = '../../data/raw/df.xlsx'
df = pd.read_excel(filepath)

# 人口が欠損している行を抽出
empty_population_rows = df[df['populations'].isna()]
len(empty_population_rows)
# Out:
# 219

# %%
check_year = 1990
empty_population_rows[empty_population_rows['years'] == check_year]
# Out:
#      island_names  years  island_ids region_codes region_names  \
# 123          瀬戸ヶ島   1990          67        32202          浜田市
# 242            長島   1990          72        33362       （旧）邑久町
# 253      前島_黄島_黒島   1990          73        33361          牛窓町
# 657            向島   1990          91        34205          尾道市
# 668           岩子島   1990          92        34205          尾道市
# 716            因島   1990          94        34206       （旧）因島市
# 797          大久野島   1990          99        34203          竹原市
# 808            契島   1990         100        34427       （旧）大崎町
# 1052           鹿島   1990         112        34202           呉市
# 1063          大芝島   1990         113        34422      （旧）安芸津町
# 1074           似島   1990         114        34100          広島市
# 1085          金輪島   1990         115        34100          広島市
# 1096          宇品島   1990         116        34100          広島市
# 1121          沖野島   1990         118        34330       （旧）大柿町
# ...
